# %%
#question 1
import numpy as np
import matplotlib.pyplot as plt
M = int(input("enter value:"))
x = np.linspace(-10,10,100)
y1=M*(x**2)
y2=M*np.sin(x)
plt.plot(x,y1,label="y=mx^2")
plt.plot(x,y2,label="y=mxsin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid()
plt.show()
# Out:
# enter value:4

# %%
#question 2
import numpy as np
import matplotlib.pyplot as plt
#question 2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = {
    "Subjects" : ["English", "Information Practices", "Physics", "Maths", "Chemistry"],
    "Score" : [95,97,92,99,96]
}
df = pd.DataFrame(data)
graph = sns.barplot(x="Subjects", y="Score", data=df, palette = 'husl')
graph.set_title("Subject Scores")
graph.set_xlabel("Subjects")
graph.set_ylabel("Score")
graph.grid()
for p in graph.patches:
  graph.annotate(str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()
# Out:
# <ipython-input-10-2df13f44a106>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   graph = sns.barplot(x="Subjects", y="Score", data=df, palette = 'husl')

# %%
#question 3
import numpy as np
import matplotlib.pyplot as plt

roll_number = int(input('enter roll number: '))
np.random.seed(roll_number)
dataset = np.random.randn(50)
print(dataset)


fig, axs = plt.subplots(1,2)
axs[0].plot(dataset)
axs[0].set_title('cumulative sum')
axs[0].set_xlabel('x-axis')
axs[0].set_ylabel('y-axis')
axs[0].grid()

axs[1].scatter(np.random.rand(30), np.random.rand(30))
axs[1].set_title('scatter plot')
axs[1].set_xlabel('x-axis')
axs[1].set_ylabel('y-axis')
axs[1].grid()

plt.show()
# Out:
# enter roll number: 102317282
# [ 1.09921845  0.17909788  0.67931169 -0.13574168 -0.21591444 -0.11242468
#  -0.97461752 -0.6589596   0.05860217 -1.08351239  1.22209996  0.38030869
#  -0.48168696 -2.77021267  0.32519796  1.25003582  2.900162    0.59642346
#   0.22945674 -0.80046059 -1.05820772  0.22257162  1.1383263   0.50887052
#  -2.02796006  0.45916608 -0.01567176  0.59546812 -1.43615483 -0.27043442
#  -1.44592889 -1.08623406  0.24458499  2.44639214 -0.69456075 -1.75171308
#  -1.96514221  1.38858977  1.17214327  0.19158367  0.93348749 -1.35501402
#  -1.26309595  0.0642226   0.52456778 -2.24863087  1.37573906 -1.24784358
#   0.41211005 -0.62815631]

# %%
#question 4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url ="https://raw.githubusercontent.com/AnjulaMehto/MCA/main/company_sales_data.csv"
data = pd.read_csv(url)
data.head()

sns.lineplot(x="month_number", y="total_profit", data=data)
plt.show()

for col in data.columns[1:6]:
  sns.lineplot(x="month_number", y=data[col],label = col, data=data)

plt.show()

for col in data.columns[1:6]:
  sns.barplot(x="month_number", y=data[col],label = col, data=data, alpha = 0.3)

plt.show()
